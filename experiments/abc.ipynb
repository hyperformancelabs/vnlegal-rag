# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd vnlegal-rag/experiments
# Out:
# /content/vnlegal-rag/vnlegal-rag/experiments

# %%
# !ls
# Out:
# demo_siamese_bilstm1l_ui.py	    textcnn_k2.ipynb
# retrieval_eval.py		    textcnn_k3.ipynb
# shared_embedding_artifacts	    textcnn_k4_artifacts
# shared_embedding_artifacts_ab	    textcnn_k4_artifacts.zip
# shared_embedding_artifacts_resplit  textcnn_k4_d02.ipynb
# siamese_256_artifacts		    textcnn_k4_d03.ipynb
# siamese_256_artifacts.zip	    textcnn_k4_d07.ipynb
# siamese-bilstm512.ipynb		    textcnn_k4_ed03.ipynb
# siamese-bilstm.ipynb		    textcnn_k4.ipynb
# SIAMESE_COMPARISON.md		    textcnn_load.py
# test-pipeline-src.ipynb		    train-siamese-bilstm-1L.ipynb
# textcnn_artifacts		    train-siamese-bilstm-2L.ipynb
# textcnn_artifacts_legacy	    train-siamese-lstm-uni.ipynb
# TEXTCNN_COMPARISON.md		    train-textcnn-ablation.ipynb
# textcnn.ipynb			    train-textcnn.ipynb

# %%
# !cp textcnn_k4_artifacts.zip /content/drive/MyDrive/textcnn_k4_artifacts.zip

# %%
# !cp siamese_256_artifacts.zip /content/drive/MyDrive/siamese_256_artifacts.zip
